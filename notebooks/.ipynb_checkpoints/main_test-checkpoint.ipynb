# %%
# Librairies

import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

import sys
import os
sys.path.append(os.path.abspath('../src'))

from graph.graphic import Graphic



graph = Graphic()
graph.barplot_wishlist()
# Out:
# 2025-06-20 13:03:42,128 - INFO - Affichage des colonnes de books.csv ayant plusieurs types de données
# 2025-06-20 13:03:42,246 - WARNING - Colonne 'isbn' contient plusieurs types
#
# 2025-06-20 13:03:42,249 - WARNING -   - str: 9300 lignes
#
# 2025-06-20 13:03:42,251 - WARNING -   - float: 700 lignes
#
# 2025-06-20 13:03:42,334 - WARNING - Colonne 'original_title' contient plusieurs types
#
# 2025-06-20 13:03:42,339 - WARNING -   - str: 9415 lignes
#
# 2025-06-20 13:03:42,343 - WARNING -   - float: 585 lignes
#
# 2025-06-20 13:03:42,377 - WARNING - Colonne 'language_code' contient plusieurs types
#
# 2025-06-20 13:03:42,381 - WARNING -   - str: 8916 lignes
#
# 2025-06-20 13:03:42,385 - WARNING -   - float: 1084 lignes
#
# 2025-06-20 13:03:42,560 - INFO - Vérification des doublons
#
# 2025-06-20 13:03:42,659 - INFO - 0 doublons détectés dans books.csv
#
# 2025-06-20 13:03:42,665 - INFO - Valeurs manquantes dans books.csv
# 2025-06-20 13:03:42,734 - INFO - 10000 lignes dans le Dataframe books
#
# 2025-06-20 13:03:42,739 - INFO - 2140 Lignes supprimées pour valeurs manquantes dans books
#
# 2025-06-20 13:03:42,759 - INFO - Le DataFrame books contient 7860 lignes
# 2025-06-20 13:03:42,920 - INFO - Affichage des colonnes de tags.csv ayant plusieurs types de données
# 2025-06-20 13:03:43,003 - INFO - Aucune colonne avec types mixtes détectée
#
# 2025-06-20 13:03:43,006 - INFO - Vérification des doublons
#
# 2025-06-20 13:03:43,060 - INFO - 0 doublons détectés dans tags.csv
#
# 2025-06-20 13:03:43,067 - INFO - Valeurs manquantes dans tags.csv
# 2025-06-20 13:03:43,116 - INFO - 34252 lignes dans le Dataframe tags
#
# 2025-06-20 13:03:43,129 - INFO - Le DataFrame tags contient 34252 lignes
# 2025-06-20 13:03:44,574 - INFO - Affichage des colonnes de book_tags.csv ayant plusieurs types de données
# 2025-06-20 13:03:47,677 - INFO - Aucune colonne avec types mixtes détectée
#
# 2025-06-20 13:03:47,679 - INFO - Vérification des doublons
#
# 2025-06-20 13:03:48,258 - INFO - 6 doublons détectés dans book_tags.csv
#
# 2025-06-20 13:03:48,844 - INFO - 999912 lignes dans le Dataframe book_tags
#
# 2025-06-20 13:03:48,848 - INFO - 6 Lignes dupliquées ont été supprimées dans book_tags
#
# 2025-06-20 13:03:48,858 - INFO - Valeurs manquantes dans book_tags.csv
# 2025-06-20 13:03:48,964 - INFO - 999906 lignes dans le Dataframe book_tags
#
# 2025-06-20 13:03:49,013 - INFO - Le DataFrame book_tags contient 999906 lignes
# 2025-06-20 13:03:49,883 - INFO - Affichage des colonnes de ratings.csv ayant plusieurs types de données
# 2025-06-20 13:03:52,832 - INFO - Aucune colonne avec types mixtes détectée
#
# 2025-06-20 13:03:52,836 - INFO - Vérification des doublons
#
# 2025-06-20 13:03:53,238 - INFO - 1644 doublons détectés dans ratings.csv
#
# 2025-06-20 13:03:53,696 - INFO - 981756 lignes dans le Dataframe ratings
#
# 2025-06-20 13:03:53,699 - INFO - 1644 Lignes dupliquées ont été supprimées dans ratings
#
# 2025-06-20 13:03:53,704 - INFO - Valeurs manquantes dans ratings.csv
# 2025-06-20 13:03:53,779 - INFO - 980112 lignes dans le Dataframe ratings
#
# 2025-06-20 13:03:53,795 - INFO - Le DataFrame ratings contient 980112 lignes
# 2025-06-20 13:03:54,469 - INFO - Affichage des colonnes de to_read.csv ayant plusieurs types de données
# 2025-06-20 13:03:56,309 - INFO - Aucune colonne avec types mixtes détectée
#
# 2025-06-20 13:03:56,312 - INFO - Vérification des doublons
#
# 2025-06-20 13:03:56,619 - INFO - 0 doublons détectés dans to_read.csv
#
# 2025-06-20 13:03:56,627 - INFO - Valeurs manquantes dans to_read.csv
# 2025-06-20 13:03:56,662 - INFO - 912705 lignes dans le Dataframe to_read
#
# 2025-06-20 13:03:56,692 - INFO - Le DataFrame to_read contient 912705 lignes
# 2025-06-20 13:03:56,734 - INFO - 7860 lignes dans le Dataframe books
#
# 2025-06-20 13:03:56,737 - INFO - 5 Lignes supprimées pour valeurs manquantes dans books
#
# 2025-06-20 13:03:57,533 - INFO - 34252 lignes dans le Dataframe tags
#
# 2025-06-20 13:03:57,535 - INFO - 1 Lignes supprimées pour valeurs manquantes dans tags
#
# 2025-06-20 13:03:57,700 - INFO - 999906 lignes dans le Dataframe book_tags
#
# 2025-06-20 13:03:57,745 - INFO - Valeurs sans correspondance dans tags_clean :
# 2025-06-20 13:03:57,894 - INFO - 999899 lignes dans le Dataframe book_tags
#
# 2025-06-20 13:03:57,987 - INFO - Valeurs sans correspondance dans books_clean :
# 2025-06-20 13:03:58,058 - INFO - 999906 lignes dans le Dataframe book_tags
#
# 2025-06-20 13:03:58,061 - INFO - 214415 Lignes supprimées pour valeurs manquantes dans book_tags
#
# 2025-06-20 13:03:58,108 - INFO - 980112 lignes dans le Dataframe ratings
#
# 2025-06-20 13:03:58,270 - INFO - Valeurs sans correspondance dans books_clean pour ratings :
# 2025-06-20 13:03:58,292 - INFO - 66370 lignes dans le Dataframe ratings
#
# 2025-06-20 13:03:58,300 - INFO - 66370 lignes dans le Dataframe ratings
#
# 2025-06-20 13:03:58,306 - INFO - 980112 lignes dans le Dataframe ratings
#
# 2025-06-20 13:03:58,310 - INFO - 913742 Lignes supprimées pour valeurs manquantes dans ratings
#
# 2025-06-20 13:03:58,407 - INFO - 912705 lignes dans le Dataframe to_read
#
# 2025-06-20 13:03:58,576 - INFO - Valeurs sans correspondance dans books_clean pour to_read :
# 2025-06-20 13:03:58,594 - INFO - 912705 lignes dans le Dataframe to_read
#
# 2025-06-20 13:03:58,597 - INFO - 835967 Lignes supprimées pour valeurs manquantes dans to_read

# %% [markdown]
# Graph2

# %%
graph.barplot_ratings()
# Out:
# 2025-06-20 13:03:58,976 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# /home/dine/Dev/python_ynov/Projet 4/src/graph.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=mean_ratings, x='user_id', y='rating', palette='Set2')
# 2025-06-20 13:03:59,033 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-06-20 13:04:00,634 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# /home/dine/Dev/python_ynov/Projet 4/src/graph.py:91: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=mean_diff_per_user, x='user_id', y='rating_diff', palette='coolwarm')
# 2025-06-20 13:04:00,684 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
